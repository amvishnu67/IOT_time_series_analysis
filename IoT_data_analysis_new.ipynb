# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# %%
df = pd.read_csv('Dataset.csv', parse_dates=['Datetime'])

# %%
df.head()
df.shape, df.columns, df.dtypes
# Out:
# ((7056, 2),
#  Index(['Datetime', 'Hourly_Temp'], dtype='object'),
#  Datetime       datetime64[ns]
#  Hourly_Temp           float64
#  dtype: object)

# %%
df = df.drop(columns=["Unnamed: 0"])
df.head()
# Out:
#              Datetime  Hourly_Temp
# 0 2022-01-04 00:00:00       20.867
# 1 2022-01-04 01:00:00       21.000
# 2 2022-01-04 02:00:00       20.867
# 3 2022-01-04 03:00:00       20.650
# 4 2022-01-04 04:00:00       20.400

# %%
# df = df.sort_values("Datetime").set_index("Datetime")
# df.index.freq
df.head()
# Out:
#                      Hourly_Temp
# Datetime
# 2022-01-04 00:00:00       20.867
# 2022-01-04 01:00:00       21.000
# 2022-01-04 02:00:00       20.867
# 2022-01-04 03:00:00       20.650
# 2022-01-04 04:00:00       20.400

# %%
type(df.index)
df.index.inferred_freq
# Out:
# 'h'

# %% [markdown]
# h ==> This means perfect hourly data

# %%
y = df["Hourly_Temp"].asfreq("h")
y.head()
# Out:
# Datetime
# 2022-01-04 00:00:00    20.867
# 2022-01-04 01:00:00    21.000
# 2022-01-04 02:00:00    20.867
# 2022-01-04 03:00:00    20.650
# 2022-01-04 04:00:00    20.400
# Freq: h, Name: Hourly_Temp, dtype: float64

# %%
y.plot(figsize=(12,4), title="Hourly Temperature (after setting time index)")
plt.show()

# %%
y.isna().sum()
# y.index.freq %% Sum is zero and sampled hourly with no missing timestamps
# Out:
# 0
